# %%
# https://velog.io/@krec7748/Pytorch-EfficientNet-%EA%B5%AC%ED%98%84

# %%
#https://keep-steady.tistory.com/35

# %%
# !git clone https://github.com/lukemelas/EfficientNet-PyTorch
# !cd EfficientNet-PyTorch && pip install -e .
# Out:
# Cloning into 'EfficientNet-PyTorch'...
# remote: Enumerating objects: 665, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 665 (delta 26), reused 58 (delta 23), pack-reused 595 (from 1)
# Receiving objects: 100% (665/665), 1.14 MiB | 20.89 MiB/s, done.
# Resolving deltas: 100% (341/341), done.
# Obtaining file:///content/EfficientNet-PyTorch
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch==0.7.1) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch==0.7.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->efficientnet_pytorch==0.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch==0.7.1) (3.0.2)
# Installing collected packages: efficientnet_pytorch
#   Running setup.py develop for efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
pip show efficientnet-pytorch
# Out:
# Name: efficientnet_pytorch
# Version: 0.7.1
# Summary: EfficientNet implemented in PyTorch.
# Home-page: https://github.com/lukemelas/EfficientNet-PyTorch
# Author: Luke
# Author-email: lmelaskyriazi@college.harvard.edu
# License: Apache
# Location: /content/EfficientNet-PyTorch
# Editable project location: /content/EfficientNet-PyTorch
# Requires: torch
# Required-by:

# %% [markdown]
# 위에 두개 코드 실행 후 런타임 -> 세션 다시 시작 누르고 밑에 efficientnet import하는 코드 잘 돌아가는지 확인해준 다음에 데이터 불러오기 부분부터 하시면 됩니다

# %%
# from efficientnet_pytorch import EfficientNet
# model = EfficientNet.from_name('efficientnet-b0')

# pre-trained
# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Requirement already satisfied: efficientnet_pytorch in ./EfficientNet-PyTorch (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->efficientnet_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (3.0.2)
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 188MB/s]
# Loaded pretrained weights for efficientnet-b0

# %%
# cuda delete cache
import torch
torch.cuda.empty_cache()

# %% [markdown]
# ## 데이터 불러오기

# %%
import torch
import random

# 시드(seed) 고정
random_seed = 1234
torch.manual_seed(random_seed)
import numpy as np
np.random.seed(random_seed)
random.seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# 구글 드라이브와 연동
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# 지정한 경로의 파일 및 폴더 목록 가져오기
files = os.listdir('/content/drive/MyDrive/Colab Notebooks/SolarPanel_Datasets')  # 디렉토리 경로를 지정하세요.
print(files)
# Out:
# ['train', 'test']

# %%
import cv2
import numpy as np

target_size = (224,224)

def load_dataset(groups_folder_path, categories):

    Y = []
    X = []

    for idx, category in enumerate(categories):
        label = idx  # 정수 레이블로 변경
        image_dir = os.path.join(groups_folder_path, category)

        file_list = os.listdir(image_dir)

        for filename in file_list:
            if filename.lower().endswith('.jpg'):
                url = os.path.join(image_dir, filename)
                img = cv2.imread(url)
                if img is not None:  # 이미지를 성공적으로 읽었는지 확인
                     img_resized = cv2.resize(img, target_size)
                     X.append(img_resized)
                     Y.append(label)

    return X, Y

train_folder_path = os.path.join('/content/drive/MyDrive/Colab Notebooks/SolarPanel_Datasets', 'train')
test_folder_path = os.path.join('/content/drive/MyDrive/Colab Notebooks/SolarPanel_Datasets', 'test')

categories = ['Physical-Damage', 'Electrical-damage', 'Snow-Covered', 'Dusty', 'Bird-drop', 'Clean']

X_train, Y_train = load_dataset(train_folder_path, categories)
X_test, Y_test = load_dataset(test_folder_path, categories)

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

print(f"train 이미지 데이터 shape: {X_train.shape}")
print(f"train 레이블 데이터 shape: {Y_train.shape}")

print(f"test 이미지 데이터 shape: {X_test.shape}")
print(f"test 레이블 데이터 shape: {Y_test.shape}")

print(np.unique(Y_train, return_counts=True))
print(np.unique(Y_test, return_counts=True))
# Out:
# train 이미지 데이터 shape: (701, 224, 224, 3)
# train 레이블 데이터 shape: (701,)
# test 이미지 데이터 shape: (176, 224, 224, 3)
# test 레이블 데이터 shape: (176,)
# (array([0, 1, 2, 3, 4, 5]), array([ 55,  80,  98, 152, 163, 153]))
# (array([0, 1, 2, 3, 4, 5]), array([14, 19, 25, 38, 42, 38]))

# %%
import matplotlib.pyplot as plt

# 클래스별로 이미지 하나씩 시각화
num_classes = len(categories)

# 각 클래스의 첫 번째 이미지 인덱스 찾기
class_first_indices = [np.where(Y_train == i)[0][0] for i in range(num_classes)]

# 이미지 출력 설정
plt.figure(figsize=(10, 5))
for i, idx in enumerate(class_first_indices):
    plt.subplot(2, 4, i + 1)  # 2행 5열의 subplot을 만들고 각 클래스별 이미지 출력
    plt.imshow(X_train[idx])
    plt.title(categories[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## train, validation 분리 & 전처리

# %%
from sklearn.model_selection import train_test_split

# 1. 전체 데이터에서 훈련 데이터(80%)와 검증 데이터(20%) 분할
x_train, x_valid, y_train, y_valid = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)


# 분할된 데이터 크기 확인
print(f"훈련 데이터 크기: {x_train.shape}")
print("y_train shape:", y_train.shape)
print(f"검증 데이터 크기: {x_valid.shape}")
print("y_valid shape:", y_valid.shape)

print("x_test shape:", X_test.shape)
print("y_test shape:", Y_test.shape)
# Out:
# 훈련 데이터 크기: (560, 224, 224, 3)
# y_train shape: (560,)
# 검증 데이터 크기: (141, 224, 224, 3)
# y_valid shape: (141,)
# x_test shape: (176, 224, 224, 3)
# y_test shape: (176,)

# %% [markdown]
# 전처리

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# For normalization, ImageNet 데이터셋에 사용된 평균과 표준편차 사용
in_mean = (0.485, 0.456, 0.406)
in_std = (0.229, 0.224, 0.225)

# 데이터 증강 정의 (학습 데이터셋에만 적용)

# transofrms.Normalize((R채널 평균, G채널 평균, B채널 평균), (R채널 표준편차, G채널 표준편차, B채널 표준편차))

# 증강 확률의 기본값은 0.5
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.RandomVerticalFlip(), # 상하 반전
    transforms.RandomHorizontalFlip(), # 좌우 반전
    #transforms.RandomRotation(90), #  (-degree, +degree) 사이만큼 회전
    transforms.RandomGrayscale(), # 흑백화
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.RandomErasing(),
    #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), #색상 변화에 강한 모델
    #transforms.RandomResizedCrop(size=224, scale=(0.8, 1.0)),# 크기를 80%~100% 범위로 자른 후 크기를 맞춤
    #transforms.RandomAffine(degrees=30, translate=(0.1, 0.1), scale=(0.8, 1.2)), # 이동, 회전, 크기 변경 등을 한 번에 적용
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

# 검증 및 테스트 데이터셋에는 증강 적용 안 함
test_transform = transforms.Compose([
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

class CustomDataset(Dataset):
    def __init__(self, X, y, mode='train'):  # mode 인자 추가
        self.X = X
        self.y = torch.tensor(y, dtype=torch.long)
        self.mode = mode  # mode 저장

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.mode == 'train':
            x = train_transform(x)
        else:  # 'valid' 또는 'test'
            x = test_transform(x)
        y = self.y[idx]
        return x, y

# Dataset 생성
train_dataset = CustomDataset(x_train, y_train, mode='train')    #증강 적용
valid_dataset = CustomDataset(x_valid, y_valid, mode='valid')
test_dataset = CustomDataset(X_test, Y_test, mode='test')


## data loader 선언
dataloaders, batch_num = {}, {}
batch_size = 32

dataloaders['train'] = DataLoader(train_dataset,batch_size=batch_size, shuffle=True)   # 학습 로더에서 나오는 데이터는 항상 섞어줍니다
dataloaders['valid'] = DataLoader(valid_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다
dataloaders['test'] = DataLoader(test_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다

batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  train,valid,test : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 32,  train,valid,test : 18 / 5 / 6

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
import torchvision

# 첫 번째 배치 데이터 가져오기
for i, (images, labels) in enumerate(dataloaders['train']):
    print(f"train batch {i}: {images.shape}")
    break

# Figure 크기 설정
plt.figure(figsize=(15, 10))
print(labels)
# 이미지 시각화
img_grid = torchvision.utils.make_grid(images)
plt.imshow(img_grid.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# train batch 0: torch.Size([32, 3, 224, 224])
# tensor([4, 2, 5, 1, 4, 3, 4, 3, 3, 5, 3, 3, 5, 2, 2, 5, 2, 4, 3, 2, 4, 5, 1, 5,
#         0, 3, 5, 4, 4, 5, 4, 2])

# %% [markdown]
# ## 모델

# %% [markdown]
# ### efficientnet-b0

# %% [markdown]
# transfer learning

# %% [markdown]
# ### 모든 레이어 freeze

# %% [markdown]
# ### batch size = 32

# %% [markdown]
# #### lr = 0.05

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.23 Acc: 56.1
# valid Loss: 2.85 Acc: 29.8
# ==> best model saved - 0 / 29.8
# Epoch 1/99
# ----------
# train Loss: 0.65 Acc: 77.3
# valid Loss: 3.38 Acc: 27.0
# Epoch 2/99
# ----------
# train Loss: 0.47 Acc: 83.8
# valid Loss: 1.94 Acc: 50.4
# ==> best model saved - 2 / 50.4
# Epoch 3/99
# ----------
# train Loss: 0.35 Acc: 87.9
# valid Loss: 3.87 Acc: 41.1
# Epoch 4/99
# ----------
# train Loss: 0.40 Acc: 86.2
# valid Loss: 1.46 Acc: 69.5
# ==> best model saved - 4 / 69.5
# Epoch 5/99
# ----------
# train Loss: 0.35 Acc: 88.9
# valid Loss: 1.94 Acc: 70.2
# ==> best model saved - 5 / 70.2
# Epoch 6/99
# ----------
# train Loss: 0.31 Acc: 89.8
# valid Loss: 1.60 Acc: 68.8
# Epoch 7/99
# ----------
# train Loss: 0.28 Acc: 90.5
# valid Loss: 2.37 Acc: 61.0
# Epoch 8/99
# ----------
# train Loss: 0.12 Acc: 94.8
# valid Loss: 1.75 Acc: 66.7
# Epoch 9/99
# ----------
# train Loss: 0.15 Acc: 96.1
# valid Loss: 1.11 Acc: 73.0
# ==> best model saved - 9 / 73.0
# Epoch 10/99
# ----------
# train Loss: 0.11 Acc: 96.6
# valid Loss: 1.11 Acc: 73.8
# ==> best model saved - 10 / 73.8
# Epoch 11/99
# ----------
# train Loss: 0.09 Acc: 97.5
# valid Loss: 1.23 Acc: 75.9
# ==> best model saved - 11 / 75.9
# Epoch 12/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 1.22 Acc: 76.6
# ==> best model saved - 12 / 76.6
# Epoch 13/99
# ----------
# train Loss: 0.06 Acc: 98.8
# valid Loss: 0.90 Acc: 83.7
# ==> best model saved - 13 / 83.7
# Epoch 14/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.87 Acc: 83.7
# Epoch 15/99
# ----------
# train Loss: 0.05 Acc: 98.2
# valid Loss: 1.03 Acc: 78.7
# Epoch 16/99
# ----------
# train Loss: 0.07 Acc: 97.7
# valid Loss: 1.41 Acc: 80.1
# Epoch 17/99
# ----------
# train Loss: 0.07 Acc: 97.3
# valid Loss: 0.99 Acc: 83.0
# Epoch 18/99
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 1.03 Acc: 82.3
# Epoch 19/99
# ----------
# train Loss: 0.06 Acc: 98.0
# valid Loss: 0.91 Acc: 86.5
# ==> best model saved - 19 / 86.5
# Epoch 20/99
# ----------
# train Loss: 0.05 Acc: 97.7
# valid Loss: 0.97 Acc: 82.3
# Epoch 21/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 1.18 Acc: 78.7
# Epoch 22/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 0.99 Acc: 84.4
# Epoch 23/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0
# ----------
# train Loss: 0.42 Acc: 87.3
# valid Loss: 1.11 Acc: 68.1
# ==> best model saved - 3 / 68.1
# Epoch 4/99
# ----------
# train Loss: 0.27 Acc: 92.7
# valid Loss: 1.03 Acc: 72.3
# ==> best model saved - 4 / 72.3
# Epoch 5/99
# ----------
# train Loss: 0.26 Acc: 92.9
# valid Loss: 0.80 Acc: 78.0
# ==> best model saved - 5 / 78.0
# Epoch 6/99
# ----------
# train Loss: 0.19 Acc: 93.8
# valid Loss: 0.74 Acc: 77.3
# Epoch 7/99
# ----------
# train Loss: 0.15 Acc: 97.7
# valid Loss: 0.76 Acc: 79.4
# ==> best model saved - 7 / 79.4
# Epoch 8/99
# ----------
# train Loss: 0.13 Acc: 96.4
# valid Loss: 0.72 Acc: 82.3
# ==> best model saved - 8 / 82.3
# Epoch 9/99
# ----------
# train Loss: 0.11 Acc: 97.0
# valid Loss: 0.68 Acc: 82.3
# Epoch 10/99
# ----------
# train Loss: 0.08 Acc: 98.2
# valid Loss: 0.65 Acc: 81.6
# Epoch 11/99
# ----------
# train Loss: 0.08 Acc: 98.0
# valid Loss: 0.67 Acc: 83.0
# ==> best model saved - 11 / 83.0
# Epoch 12/99
# ----------
# train Loss: 0.09 Acc: 96.8
# valid Loss: 0.60 Acc: 84.4
# ==> best model saved - 12 / 84.4
# Epoch 13/99
# ----------
# train Loss: 0.07 Acc: 98.6
# valid Loss: 0.64 Acc: 85.1
# ==> best model saved - 13 / 85.1
# Epoch 14/99
# ----------
# train Loss: 0.08 Acc: 98.0
# valid Loss: 0.60 Acc: 85.1
# Epoch 15/99
# ----------
# train Loss: 0.06 Acc: 98.8
# valid Loss: 0.62 Acc: 85.1
# Epoch 16/99
# ----------
# train Loss: 0.08 Acc: 97.9
# valid Loss: 0.67 Acc: 82.3
# Epoch 17/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.66 Acc: 83.0
# Epoch 18/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.65 Acc: 85.1
# Epoch 19/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 0.62 Acc: 85.1
# Epoch 20/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.60 Acc: 84.4
# Epoch 21/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.62 Acc: 82.3
# Epoch 22/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.63 Acc: 83.0
# Epoch 23/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 0.70 Acc: 83.0
# Epoch 24/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.66 Acc: 83.7
# Epoch 25/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 0.70 Acc: 81.6
# Epoch 26/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.66 Acc: 82.3
# Epoch 27/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.62 Acc: 85.1
# Epoch 28/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.66 Acc: 83.0
# Epoch 29/99
# ----------
# train Loss: 0.04 Acc: 99.3
# valid Loss: 0.64 Acc: 85.8
# ==> best model saved - 29 / 85.8
# Epoch 30/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 85.8
# Epoch 31/99
# ----------
# train Loss: 0.04 Acc: 99.3
# valid Loss: 0.64 Acc: 83.7
# Epoch 32/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.66 Acc: 83.7
# Epoch 33/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.68 Acc: 83.7
# Epoch 34/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.67 Acc: 85.1
# Epoch 35/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.65 Acc: 85.1
# Epoch 36/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.68 Acc: 85.1
# Epoch 37/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.69 Acc: 84.4
# Epoch 38/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.70 Acc: 84.4
# Epoch 39/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.70 Acc: 84.4
# Epoch 40/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.70 Acc: 83.0
# Epoch 41/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.69 Acc: 83.0
# Epoch 42/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 0.69 Acc: 81.6
# Epoch 43/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.68 Acc: 81.6
# Epoch 44/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.70 Acc: 81.6
# Epoch 45/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.70 Acc: 82.3
# Epoch 46/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.70 Acc: 81.6
# Epoch 47/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.70 Acc: 81.6
# Epoch 48/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.67 Acc: 83.0
# Epoch 49/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.66 Acc: 85.1
# Epoch 50/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.66 Acc: 84.4
# Epoch 51/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.65 Acc: 85.1
# Epoch 52/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.65 Acc: 83.0
# Epoch 53/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 54/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.63 Acc: 85.8
# Epoch 55/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0
99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.65 Acc: 84.4
# Epoch 51/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.65 Acc: 84.4
# Epoch 52/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.65 Acc: 84.4
# Epoch 53/99
# ----------
# train Loss: 0.07 Acc: 97.9
# valid Loss: 0.64 Acc: 84.4
# Epoch 54/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.63 Acc: 84.4
# Epoch 55/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 56/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 0.64 Acc: 84.4
# Epoch 57/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 0.64 Acc: 84.4
# Epoch 58/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.64 Acc: 83.7
# Epoch 59/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 60/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 0.64 Acc: 84.4
# Epoch 61/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 62/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.63 Acc: 84.4
# Epoch 63/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.63 Acc: 84.4
# Epoch 64/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.63 Acc: 84.4
# Epoch 65/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.63 Acc: 84.4
# Epoch 66/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.63 Acc: 84.4
# Epoch 67/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.64 Acc: 84.4
# Epoch 68/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 69/99
# ----------
# train Loss: 0.02 Acc: 100.0
# valid Loss: 0.64 Acc: 84.4
# Epoch 70/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.65 Acc: 83.7
# Epoch 71/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.64 Acc: 83.7
# Epoch 72/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 73/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.64 Acc: 84.4
# Epoch 74/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 75/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.64 Acc: 84.4
# Epoch 76/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.64 Acc: 84.4
# Epoch 77/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 78/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.65 Acc: 83.7
# Epoch 79/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.65 Acc: 83.7
# Epoch 80/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.65 Acc: 83.7
# Epoch 81/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.65 Acc: 83.7
# Epoch 82/99
# ----------
# train Loss: 0.05 Acc: 98.0
# valid Loss: 0.65 Acc: 83.7
# Epoch 83/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.66 Acc: 83.7
# Epoch 84/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.67 Acc: 84.4
# Epoch 85/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.66 Acc: 84.4
# Epoch 86/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.66 Acc: 83.7
# Epoch 87/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.66 Acc: 83.7
# Epoch 88/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.65 Acc: 83.7
# Epoch 89/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.66 Acc: 84.4
# Epoch 90/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.66 Acc: 84.4
# Epoch 91/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.66 Acc: 83.7
# Epoch 92/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.66 Acc: 83.7
# Epoch 93/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.66 Acc: 83.7
# Epoch 94/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.66 Acc: 83.7
# Epoch 95/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.67 Acc: 83.7
# Epoch 96/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.67 Acc: 83.7
# Epoch 97/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.67 Acc: 83.0
# Epoch 98/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.67 Acc: 83.7
# Epoch 99/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.67 Acc: 83.7
# Training complete in 7m 50s
# Best valid Acc: 21 - 85.1
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 21 - 85 / 0.6

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_3.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_3.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-49-7f564a745d0c>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_3.pt'))
# Test Loss: 0.5613
# Test Accuracy: 82.95%

# %% [markdown]
# ### batch size = 64

# %% [markdown]
# #### lr = 0.05

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# For normalization, ImageNet 데이터셋에 사용된 평균과 표준편차 사용
in_mean = (0.485, 0.456, 0.406)
in_std = (0.229, 0.224, 0.225)

# 데이터 증강 정의 (학습 데이터셋에만 적용)

# transofrms.Normalize((R채널 평균, G채널 평균, B채널 평균), (R채널 표준편차, G채널 표준편차, B채널 표준편차))

# 증강 확률의 기본값은 0.5
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.RandomVerticalFlip(), # 상하 반전
    transforms.RandomHorizontalFlip(), # 좌우 반전
    #transforms.RandomRotation(90), #  (-degree, +degree) 사이만큼 회전
    transforms.RandomGrayscale(), # 흑백화
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.RandomErasing(),
    #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), #색상 변화에 강한 모델
    #transforms.RandomResizedCrop(size=224, scale=(0.8, 1.0)),# 크기를 80%~100% 범위로 자른 후 크기를 맞춤
    #transforms.RandomAffine(degrees=30, translate=(0.1, 0.1), scale=(0.8, 1.2)), # 이동, 회전, 크기 변경 등을 한 번에 적용
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

# 검증 및 테스트 데이터셋에는 증강 적용 안 함
test_transform = transforms.Compose([
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

class CustomDataset(Dataset):
    def __init__(self, X, y, mode='train'):  # mode 인자 추가
        self.X = X
        self.y = torch.tensor(y, dtype=torch.long)
        self.mode = mode  # mode 저장

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.mode == 'train':
            x = train_transform(x)
        else:  # 'valid' 또는 'test'
            x = test_transform(x)
        y = self.y[idx]
        return x, y

# Dataset 생성
train_dataset = CustomDataset(x_train, y_train, mode='train')    #증강 적용
valid_dataset = CustomDataset(x_valid, y_valid, mode='valid')
test_dataset = CustomDataset(X_test, Y_test, mode='test')


## data loader 선언
dataloaders, batch_num = {}, {}
batch_size = 64

dataloaders['train'] = DataLoader(train_dataset,batch_size=batch_size, shuffle=True)   # 학습 로더에서 나오는 데이터는 항상 섞어줍니다
dataloaders['valid'] = DataLoader(valid_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다
dataloaders['test'] = DataLoader(test_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다

batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  train,valid,test : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 64,  train,valid,test : 9 / 3 / 3

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs = 100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.47 Acc: 42.5
# valid Loss: 1.67 Acc: 32.6
# ==> best model saved - 0 / 32.6
# Epoch 1/99
# ----------
# train Loss: 0.70 Acc: 74.5
# valid Loss: 1.71 Acc: 53.9
# ==> best model saved - 1 / 53.9
# Epoch 2/99
# ----------
# train Loss: 0.34 Acc: 89.1
# valid Loss: 2.00 Acc: 56.0
# ==> best model saved - 2 / 56.0
# Epoch 3/99
# ----------
# train Loss: 0.16 Acc: 94.3
# valid Loss: 2.17 Acc: 55.3
# Epoch 4/99
# ----------
# train Loss: 0.12 Acc: 96.6
# valid Loss: 2.14 Acc: 62.4
# ==> best model saved - 4 / 62.4
# Epoch 5/99
# ----------
# train Loss: 0.09 Acc: 98.0
# valid Loss: 1.82 Acc: 64.5
# ==> best model saved - 5 / 64.5
# Epoch 6/99
# ----------
# train Loss: 0.05 Acc: 99.3
# valid Loss: 1.83 Acc: 67.4
# ==> best model saved - 6 / 67.4
# Epoch 7/99
# ----------
# train Loss: 0.08 Acc: 97.5
# valid Loss: 1.71 Acc: 70.9
# ==> best model saved - 7 / 70.9
# Epoch 8/99
# ----------
# train Loss: 0.05 Acc: 97.9
# valid Loss: 1.60 Acc: 70.9
# Epoch 9/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss:
# Epoch 83/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 80.9
# Epoch 84/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 80.1
# Epoch 85/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.89 Acc: 80.9
# Epoch 86/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.90 Acc: 80.9
# Epoch 87/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.91 Acc: 80.9
# Epoch 88/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.91 Acc: 80.9
# Epoch 89/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.91 Acc: 80.9
# Epoch 90/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.90 Acc: 81.6
# Epoch 91/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.90 Acc: 81.6
# Epoch 92/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.90 Acc: 81.6
# Epoch 93/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.90 Acc: 82.3
# Epoch 94/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.89 Acc: 82.3
# Epoch 95/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.90 Acc: 83.0
# Epoch 96/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.90 Acc: 83.0
# Epoch 97/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.91 Acc: 83.0
# Epoch 98/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.91 Acc: 83.0
# Epoch 99/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.91 Acc: 83.0
# Training complete in 8m 11s
# Best valid Acc: 57 - 83.7
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 57 - 84 / 1.0

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_64_1.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_64_1.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-57-a201b0a05e3b>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_64_1.pt'))
# Test Loss: 0.6939
# Test Accuracy: 83.52%

# %% [markdown]
# #### lr = 0.01

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.01,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs = 100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.71 Acc: 29.5
# valid Loss: 1.68 Acc: 26.2
# ==> best model saved - 0 / 26.2
# Epoch 1/99
# ----------
# train Loss: 1.34 Acc: 59.5
# valid Loss: 1.56 Acc: 27.7
# ==> best model saved - 1 / 27.7
# Epoch 2/99
# ----------
# train Loss: 1.04 Acc: 68.0
# valid Loss: 1.48 Acc: 43.3
# ==> best model saved - 2 / 43.3
# Epoch 3/99
# ----------
# train Loss: 0.77 Acc: 77.3
# valid Loss: 1.49 Acc: 45.4
# ==> best model saved - 3 / 45.4
# Epoch 4/99
# ----------
# train Loss: 0.58 Acc: 83.4
# valid Loss: 1.33 Acc: 58.2
# ==> best model saved - 4 / 58.2
# Epoch 5/99
# ----------
# train Loss: 0.46 Acc: 87.5
# valid Loss: 1.26 Acc: 63.1
# ==> best model saved - 5 / 63.1
# Epoch 6/99
# ----------
# train Loss: 0.37 Acc: 90.2
# valid Loss: 1.21 Acc: 66.7
# ==> best model saved - 6 / 66.7
# Epoch 7/99
# ----------
# train Loss: 0.31 Acc: 91.4
# valid Loss: 1.13 Acc: 68.8
# ==> best model saved - 7 / 68.8
# Epoch 8/99
# ----------
# train Loss: 0.24 Acc: 94.3
# valid Loss: 1.06 Acc: 71.6
# ==> best model saved - 8 / 71.6
# Epoch 9/99
# ----------
# train Loss: 0.22 Acc: 94.8
# valid Loss: 0.96 Acc: 74.5
# ==> best model saved - 9 / 74.5
# Epoch 10/99
# ----------
# train Loss: 0.19 Acc: 94.6
# valid Loss: 0.89 Acc: 75.9
# ==> best model saved - 10 / 75.9
# Epoch 11/99
# ----------
# train Loss: 0.14 Acc: 97.1
# valid Loss: 0.83 Acc: 74.5
# Epoch 12/99
# ----------
# train Loss: 0.13 Acc: 97.1
# valid Loss: 0.76 Acc: 74.5
# Epoch 13/99
# ----------
# train Loss: 0.13 Acc: 98.0
# valid Loss: 0.73 Acc: 78.0
# ==> best model saved - 13 / 78.0
# Epoch 14/99
# ----------
# train Loss: 0.12 Acc: 96.6
# valid Loss: 0.71 Acc: 78.0
# Epoch 15/99
# ----------
# train Loss: 0.12 Acc: 96.6
# valid Loss: 0.68 Acc: 78.7
# ==> best model saved - 15 / 78.7
# Epoch 16/99
# ----------
# train Loss: 0.08 Acc: 98.9
# valid Loss: 0.67 Acc: 80.9
# ==> best model saved - 16 / 80.9
# Epoch 17/99
# ----------
# train Loss: 0.08 Acc: 98.0
# valid Loss:
99
# ----------
# train Loss: 0.06 Acc: 98.9
# valid Loss: 0.61 Acc: 83.0
# Epoch 46/99
# ----------
# train Loss: 0.07 Acc: 98.8
# valid Loss: 0.61 Acc: 82.3
# Epoch 47/99
# ----------
# train Loss: 0.07 Acc: 98.4
# valid Loss: 0.61 Acc: 82.3
# Epoch 48/99
# ----------
# train Loss: 0.06 Acc: 98.9
# valid Loss: 0.61 Acc: 82.3
# Epoch 49/99
# ----------
# train Loss: 0.06 Acc: 98.9
# valid Loss: 0.62 Acc: 83.0
# Epoch 50/99
# ----------
# train Loss: 0.06 Acc: 98.2
# valid Loss: 0.61 Acc: 83.0
# Epoch 51/99
# ----------
# train Loss: 0.05 Acc: 99.5
# valid Loss: 0.61 Acc: 83.0
# Epoch 52/99
# ----------
# train Loss: 0.06 Acc: 98.6
# valid Loss: 0.61 Acc: 83.0
# Epoch 53/99
# ----------
# train Loss: 0.07 Acc: 97.9
# valid Loss: 0.61 Acc: 83.0
# Epoch 54/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.61 Acc: 83.0
# Epoch 55/99
# ----------
# train Loss: 0.08 Acc: 98.2
# valid Loss: 0.61 Acc: 83.0
# Epoch 56/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.61 Acc: 83.0
# Epoch 57/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.61 Acc: 83.0
# Epoch 58/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 0.62 Acc: 83.0
# Epoch 59/99
# ----------
# train Loss: 0.06 Acc: 98.4
# valid Loss: 0.62 Acc: 83.7
# Epoch 60/99
# ----------
# train Loss: 0.06 Acc: 98.4
# valid Loss: 0.63 Acc: 83.7
# Epoch 61/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.63 Acc: 83.7
# Epoch 62/99
# ----------
# train Loss: 0.04 Acc: 99.5
# valid Loss: 0.62 Acc: 85.1
# ==> best model saved - 62 / 85.1
# Epoch 63/99
# ----------
# train Loss: 0.05 Acc: 99.3
# valid Loss: 0.62 Acc: 85.1
# Epoch 64/99
# ----------
# train Loss: 0.04 Acc: 99.6
# valid Loss: 0.62 Acc: 84.4
# Epoch 65/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.62 Acc: 84.4
# Epoch 66/99
# ----------
# train Loss: 0.06 Acc: 98.4
# valid Loss: 0.62 Acc: 84.4
# Epoch 67/99
# ----------
# train Loss: 0.04 Acc: 99.6
# valid Loss: 0.62 Acc: 84.4
# Epoch 68/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.62 Acc: 84.4
# Epoch 69/99
# ----------
# train Loss: 0.05 Acc: 99.1
# valid Loss: 0.62 Acc: 84.4
# Epoch 70/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.62 Acc: 84.4
# Epoch 71/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.63 Acc: 84.4
# Epoch 72/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 0.63 Acc: 85.1
# Epoch 73/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.63 Acc: 85.1
# Epoch 74/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.64 Acc: 85.1
# Epoch 75/99
# ----------
# train Loss: 0.05 Acc: 98.9
# valid Loss: 0.64 Acc: 85.8
# ==> best model saved - 75 / 85.8
# Epoch 76/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 85.1
# Epoch 77/99
# ----------
# train Loss: 0.04 Acc: 99.6
# valid Loss: 0.64 Acc: 85.1
# Epoch 78/99
# ----------
# train Loss: 0.06 Acc: 98.6
# valid Loss: 0.64 Acc: 85.1
# Epoch 79/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 85.1
# Epoch 80/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.64 Acc: 85.1
# Epoch 81/99
# ----------
# train Loss: 0.06 Acc: 98.4
# valid Loss: 0.64 Acc: 84.4
# Epoch 82/99
# ----------
# train Loss: 0.05 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 83/99
# ----------
# train Loss: 0.03 Acc: 99.8
# valid Loss: 0.64 Acc: 85.1
# Epoch 84/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 0.64 Acc: 85.1
# Epoch 85/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 85.1
# Epoch 86/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 0.64 Acc: 85.1
# Epoch 87/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.64 Acc: 85.1
# Epoch 88/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 85.1
# Epoch 89/99
# ----------
# train Loss: 0.05 Acc: 98.8
# valid Loss: 0.64 Acc: 85.8
# Epoch 90/99
# ----------
# train Loss: 0.04 Acc: 99.5
# valid Loss: 0.64 Acc: 85.1
# Epoch 91/99
# ----------
# train Loss: 0.04 Acc: 99.5
# valid Loss: 0.64 Acc: 85.1
# Epoch 92/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 0.64 Acc: 85.1
# Epoch 93/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 85.8
# Epoch 94/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.64 Acc: 85.8
# Epoch 95/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.64 Acc: 85.8
# Epoch 96/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.64 Acc: 85.8
# Epoch 97/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 0.64 Acc: 85.8
# Epoch 98/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 0.64 Acc: 85.1
# Epoch 99/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 85.1
# Training complete in 8m 9s
# Best valid Acc: 75 - 85.8
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 75 - 86 / 0.6

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_64_3.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_64_3.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-71-80e34fcbd126>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_64_3.pt'))
# Test Loss: 0.5639
# Test Accuracy: 84.09%

# %% [markdown]
# ### batch size = 128

# %% [markdown]
# #### lr = 0.05

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# For normalization, ImageNet 데이터셋에 사용된 평균과 표준편차 사용
in_mean = (0.485, 0.456, 0.406)
in_std = (0.229, 0.224, 0.225)

# 데이터 증강 정의 (학습 데이터셋에만 적용)

# transofrms.Normalize((R채널 평균, G채널 평균, B채널 평균), (R채널 표준편차, G채널 표준편차, B채널 표준편차))

# 증강 확률의 기본값은 0.5
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.RandomVerticalFlip(), # 상하 반전
    transforms.RandomHorizontalFlip(), # 좌우 반전
    #transforms.RandomRotation(90), #  (-degree, +degree) 사이만큼 회전
    transforms.RandomGrayscale(), # 흑백화
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.RandomErasing(),
    #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), #색상 변화에 강한 모델
    #transforms.RandomResizedCrop(size=224, scale=(0.8, 1.0)),# 크기를 80%~100% 범위로 자른 후 크기를 맞춤
    #transforms.RandomAffine(degrees=30, translate=(0.1, 0.1), scale=(0.8, 1.2)), # 이동, 회전, 크기 변경 등을 한 번에 적용
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

# 검증 및 테스트 데이터셋에는 증강 적용 안 함
test_transform = transforms.Compose([
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

class CustomDataset(Dataset):
    def __init__(self, X, y, mode='train'):  # mode 인자 추가
        self.X = X
        self.y = torch.tensor(y, dtype=torch.long)
        self.mode = mode  # mode 저장

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.mode == 'train':
            x = train_transform(x)
        else:  # 'valid' 또는 'test'
            x = test_transform(x)
        y = self.y[idx]
        return x, y

# Dataset 생성
train_dataset = CustomDataset(x_train, y_train, mode='train')    #증강 적용
valid_dataset = CustomDataset(x_valid, y_valid, mode='valid')
test_dataset = CustomDataset(X_test, Y_test, mode='test')


## data loader 선언
dataloaders, batch_num = {}, {}
batch_size = 128

dataloaders['train'] = DataLoader(train_dataset,batch_size=batch_size, shuffle=True)   # 학습 로더에서 나오는 데이터는 항상 섞어줍니다
dataloaders['valid'] = DataLoader(valid_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다
dataloaders['test'] = DataLoader(test_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다

batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  train,valid,test : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 128,  train,valid,test : 5 / 2 / 2

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.70 Acc: 29.6
# valid Loss: 1.63 Acc: 31.2
# ==> best model saved - 0 / 31.2
# Epoch 1/99
# ----------
# train Loss: 1.15 Acc: 65.2
# valid Loss: 2.14 Acc: 23.4
# Epoch 2/99
# ----------
# train Loss: 0.71 Acc: 78.6
# valid Loss: 2.71 Acc: 27.7
# Epoch 3/99
# ----------
# train Loss: 0.39 Acc: 87.5
# valid Loss: 2.64 Acc: 34.0
# ==> best model saved - 3 / 34.0
# Epoch 4/99
# ----------
# train Loss: 0.26 Acc: 92.0
# valid Loss: 2.69 Acc: 41.1
# ==> best model saved - 4 / 41.1
# Epoch 5/99
# ----------
# train Loss: 0.16 Acc: 95.0
# valid Loss: 2.96 Acc: 43.3
# ==> best model saved - 5 / 43.3
# Epoch 6/99
# ----------
# train Loss: 0.12 Acc: 96.6
# valid Loss: 3.27 Acc: 41.8
# Epoch 7/99
# ----------
# train Loss: 0.07 Acc: 98.0
# valid Loss: 3.24 Acc: 44.7
# ==> best model saved - 7 / 44.7
# Epoch 8/99
# ----------
# train Loss: 0.11 Acc: 96.6
# valid Loss: 2.93 Acc: 47.5
# ==> best model saved - 8 / 47.5
# Epoch 9/99
# ----------
# train Loss: 0.08 Acc: 98.0
# valid Loss: 2.52 Acc: 51.8
# ==> best model saved - 9 / 51.8
# Epoch 10/99
# ----------
# train Loss: 0.05 Acc: 98.0
# valid Loss: 2.28 Acc: 57.4
# ==> best model saved - 10 / 57.4
# Epoch 11/99
# ----------
# train Loss: 0.05 Acc: 98.0
# valid Loss: 2.18 Acc: 61.0
# ==> best model saved - 11 / 61.0
# Epoch 12/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 2.18 Acc: 63.1
# ==> best model saved - 12 / 63.1
# Epoch 13/99
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 2.08 Acc: 64.5
# ==> best model saved - 13 / 64.5
# Epoch 14/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 2.04 Acc: 63.1
# Epoch 15/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 1.96 Acc: 65.2
# ==> best model saved - 15 / 65.2
# Epoch 16/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.83 Acc: 67.4
# ==> best model saved - 16 / 67.4
# Epoch 17/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 1.72 Acc: 70.2
# ==> best model saved - 17 / 70.2
# Epoch 18/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 1.66 Acc: 69.5
# Epoch 19/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.73 Acc: 70.2
# Epoch 20/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 1.68 Acc: 68.8
# Epoch 21/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.55 Acc: 71.6
# ==> best model saved - 21 / 71.6
# Epoch 22/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.48 Acc: 73.8
# ==> best model saved - 22 / 73.8
# Epoch 23/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.44 Acc: 73.0
# Epoch 24/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.38 Acc: 73.0
# Epoch 25/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.29 Acc: 75.2
# ==> best model saved - 25 / 75.2
# Epoch 26/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 1.23 Acc: 75.2
# Epoch 27/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 1.19 Acc: 78.0
# ==> best model saved - 27 / 78.0
# Epoch 28/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.10 Acc: 80.1
# ==> best model saved - 28 / 80.1
# Epoch 29/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 1.02 Acc: 80.1
# Epoch 30/99
# ----------
# train Loss: 0.01 Acc: 100.0
# valid Loss: 0.96 Acc: 79.4
# Epoch 31/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.93 Acc: 80.1
# Epoch 32/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.91 Acc: 81.6
# ==> best model saved - 32 / 81.6
# Epoch 33/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.92 Acc: 83.7
# ==> best model saved - 33 / 83.7
# Epoch 34/99
# ----------
# train Loss: 0.01 Acc: 99.3
# valid Loss: 0.94 Acc: 83.7
# Epoch 35/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.95 Acc: 82.3
# Epoch 36/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.96 Acc: 82.3
# Epoch 37/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.94 Acc: 84.4
# ==> best model saved - 37 / 84.4
# Epoch 38/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.90 Acc: 84.4
# Epoch 39/99
# ----------
# train Loss: 0.01 Acc: 99.3
# valid Loss: 0.88 Acc: 84.4
# Epoch 40/99
# ----------
# train Loss: 0.01 Acc: 99.3
# valid Loss: 0.88 Acc: 85.1
# ==> best model saved - 40 / 85.1
# Epoch 41/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.92 Acc: 85.1
# Epoch 42/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.94 Acc: 85.1
# Epoch 43/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.93 Acc: 84.4
# Epoch 44/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.93 Acc: 84.4
# Epoch 45/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.91 Acc: 85.1
# Epoch 46/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.88 Acc: 85.1
# Epoch 47/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.83 Acc: 85.1
# Epoch 48/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.82 Acc: 83.7
# Epoch 49/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.83 Acc: 83.7
# Epoch 50/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.83 Acc: 84.4
# Epoch 51/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.84 Acc: 83.7
# Epoch 52/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.84 Acc: 83.7
# Epoch 53/99
# ----------
# train Loss: 0.01 Acc: 100.0
# valid Loss: 0.85 Acc: 83.0
# Epoch 54/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.87 Acc: 83.7
# Epoch 55/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 84.4
# Epoch 56/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 84.4
# Epoch 57/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 84.4
# Epoch 58/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.86 Acc: 85.1
# Epoch 59/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.84 Acc: 85.8
# ==> best model saved - 59 / 85.8
# Epoch 60/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.81 Acc: 85.8
# Epoch 61/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.80 Acc: 85.8
# Epoch 62/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.79 Acc: 85.8
# Epoch 63/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.79 Acc: 85.8
# Epoch 64/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.80 Acc: 85.1
# Epoch 65/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.81 Acc: 85.1
# Epoch 66/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.81 Acc: 85.1
# Epoch 67/99
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.81 Acc: 85.1
# Epoch 68/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.81 Acc: 85.1
# Epoch 69/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.81 Acc: 85.1
# Epoch 70/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.81 Acc: 84.4
# Epoch 71/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.80 Acc: 85.8
# Epoch 72/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.80 Acc: 86.5
# ==> best model saved - 72 / 86.5
# Epoch 73/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.81 Acc: 85.8
# Epoch 74/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.83 Acc: 85.1
# Epoch 75/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.83 Acc: 85.1
# Epoch 76/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.83 Acc: 85.1
# Epoch 77/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.83 Acc: 85.8
# Epoch 78/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.82 Acc: 85.8
# Epoch 79/99
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.83 Acc: 86.5
# Epoch 80/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.84 Acc: 85.8
# Epoch 81/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.85 Acc: 85.1
# Epoch 82/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.84 Acc: 84.4
# Epoch 83/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.84 Acc: 85.1
# Epoch 84/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.83 Acc: 85.8
# Epoch 85/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.84 Acc: 85.8
# Epoch 86/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.85 Acc: 85.8
# Epoch 87/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.86 Acc: 85.8
# Epoch 88/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 85.8
# Epoch 89/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 85.8
# Epoch 90/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 86.5
# Epoch 91/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 85.8
# Epoch 92/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 85.8
# Epoch 93/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 85.8
# Epoch 94/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 86.5
# Epoch 95/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 86.5
# Epoch 96/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 85.8
# Epoch 97/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.87 Acc: 85.8
# Epoch 98/99
# ----------
# train Loss: 0.01 Acc: 99.3
# valid Loss: 0.87 Acc: 85.8
# Epoch 99/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.87 Acc: 85.1
# Training complete in 8m 27s
# Best valid Acc: 72 - 86.5
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 72 - 87 / 0.8

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_128_1.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_128_1.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-79-6297e3088776>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_128_1.pt'))
# Test Loss: 0.6235
# Test Accuracy: 84.66%

# %% [markdown]
# #### lr = 0.01

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.01,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.77 Acc: 22.9
# valid Loss: 1.78 Acc: 27.7
# ==> best model saved - 0 / 27.7
# Epoch 1/99
# ----------
# train Loss: 1.59 Acc: 43.0
# valid Loss: 1.66 Acc: 29.1
# ==> best model saved - 1 / 29.1
# Epoch 2/99
# ----------
# train Loss: 1.38 Acc: 57.3
# valid Loss: 1.54 Acc: 41.8
# ==> best model saved - 2 / 41.8
# Epoch 3/99
# ----------
# train Loss: 1.19 Acc: 63.2
# valid Loss: 1.46 Acc: 44.0
# ==> best model saved - 3 / 44.0
# Epoch 4/99
# ----------
# train Loss: 1.00 Acc: 71.8
# valid Loss: 1.40 Acc: 48.2
# ==> best model saved - 4 / 48.2
# Epoch 5/99
# ----------
# train Loss: 0.87 Acc: 74.3
# valid Loss: 1.34 Acc: 52.5
# ==> best model saved - 5 / 52.5
# Epoch 6/99
# ----------
# train Loss: 0.72 Acc: 79.8
# valid Loss: 1.28 Acc: 56.7
# ==> best model saved - 6 / 56.7
# Epoch 7/99
# ----------
# train Loss: 0.61 Acc: 82.3
# valid Loss: 1.24 Acc: 58.2
# ==> best model saved - 7 / 58.2
# Epoch 8/99
# ----------
# train Loss: 0.54 Acc: 85.0
# valid Loss: 1.18 Acc: 61.7
# ==> best model saved - 8 / 61.7
# Epoch 9/99
# ----------
# train Loss: 0.46 Acc: 89.5
# valid Loss: 1.12 Acc: 65.2
# ==> best model saved - 9 / 65.2
# Epoch 10/99
# ----------
# train Loss: 0.41 Acc: 90.5
# valid Loss: 1.08 Acc: 65.2
# Epoch 11/99
# ----------
# train Loss: 0.37 Acc: 90.2
# valid Loss: 1.05 Acc: 68.1
# ==> best model saved - 11 / 68.1
# Epoch 12/99
# ----------
# train Loss: 0.34 Acc: 92.0
# valid Loss: 1.00 Acc: 69.5
# ==> best model saved - 12 / 69.5
# Epoch 13/99
# ----------
# train Loss: 0.28 Acc: 93.8
# valid Loss: 0.97 Acc: 70.9
# ==> best model saved - 13 / 70.9
# Epoch 14/99
# ----------
# train Loss: 0.27 Acc: 93.8
# valid Loss: 0.94 Acc: 71.6
# ==> best model saved - 14 / 71.6
# Epoch 15/99
# ----------
# train Loss: 0.23 Acc: 95.4
# valid Loss: 0.92 Acc: 71.6
# Epoch 16/99
# ----------
# train Loss: 0.21 Acc: 96.1
# valid Loss: 0.90 Acc: 72.3
# ==> best model saved - 16 / 72.3
# Epoch 17/99
# ----------
# train Loss: 0.21 Acc: 95.0
# valid Loss: 0.87 Acc: 72.3
# Epoch 18/99
# ----------
# train Loss: 0.20 Acc: 95.4
# valid Loss: 0.84 Acc: 73.0
# ==> best model saved - 18 / 73.0
# Epoch 19/99
# ----------
# train Loss: 0.17 Acc: 96.2
# valid Loss: 0.82 Acc: 74.5
# ==> best model saved - 19 / 74.5
# Epoch 20/99
# ----------
# train Loss: 0.16 Acc: 97.0
# valid Loss: 0.80 Acc: 75.2
# ==> best model saved - 20 / 75.2
# Epoch 21/99
# ----------
# train Loss: 0.16 Acc: 96.4
# valid Loss: 0.78 Acc: 77.3
# ==> best model saved - 21 / 77.3
# Epoch 22/99
# ----------
# train Loss: 0.14 Acc: 97.3
# valid Loss: 0.77 Acc: 78.7
# ==> best model saved - 22 / 78.7
# Epoch 23/99
# ----------
# train Loss: 0.12 Acc: 97.9
# valid Loss: 0.76 Acc: 79.4
# ==> best model saved - 23 / 79.4
# Epoch 24/99
# ----------
# train Loss: 0.14 Acc: 96.8
# valid Loss: 0.75 Acc: 78.0
# Epoch 25/99
# ----------
# train Loss: 0.11 Acc: 98.4
# valid Loss: 0.74 Acc: 78.7
# Epoch 26/99
# ----------
# train Loss: 0.12 Acc: 97.3
# valid Loss: 0.73 Acc: 78.7
# Epoch 27/99
# ----------
# train Loss: 0.11 Acc: 97.9
# valid Loss: 0.73 Acc: 78.7
# Epoch 28/99
# ----------
# train Loss: 0.10 Acc: 97.7
# valid Loss: 0.72 Acc: 78.7
# Epoch 29/99
# ----------
# train Loss: 0.08 Acc: 98.4
# valid Loss: 0.71 Acc: 78.7
# Epoch 30/99
# ----------
# train Loss: 0.09 Acc: 98.4
# valid Loss: 0
99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# ==> best model saved - 74 / 84.4
# Epoch 75/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.64 Acc: 84.4
# Epoch 76/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 77/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 78/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 79/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 80/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.64 Acc: 84.4
# Epoch 81/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 82/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.64 Acc: 84.4
# Epoch 83/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.63 Acc: 84.4
# Epoch 84/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.64 Acc: 84.4
# Epoch 85/99
# ----------
# train Loss: 0.03 Acc: 99.8
# valid Loss: 0.64 Acc: 84.4
# Epoch 86/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 87/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.64 Acc: 84.4
# Epoch 88/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 89/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 90/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.64 Acc: 84.4
# Epoch 91/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 92/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 84.4
# Epoch 93/99
# ----------
# train Loss: 0.02 Acc: 99.8
# valid Loss: 0.64 Acc: 84.4
# Epoch 94/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 95/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 84.4
# Epoch 96/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.64 Acc: 84.4
# Epoch 97/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 0.64 Acc: 83.7
# Epoch 98/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.64 Acc: 83.7
# Epoch 99/99
# ----------
# train Loss: 0.03 Acc: 99.5
# valid Loss: 0.64 Acc: 83.7
# Training complete in 8m 25s
# Best valid Acc: 74 - 84.4
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 74 - 84 / 0.6

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_128_2.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_128_2.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-86-4cd22fb39bf4>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_128_2.pt'))
# Test Loss: 0.5597
# Test Accuracy: 85.23%

# %% [markdown]
# #### lr = 0.005

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.005,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.79 Acc: 19.3
# valid Loss: 1.79 Acc: 20.6
# ==> best model saved - 0 / 20.6
# Epoch 1/99
# ----------
# train Loss: 1.69 Acc: 30.5
# valid Loss: 1.72 Acc: 27.7
# ==> best model saved - 1 / 27.7
# Epoch 2/99
# ----------
# train Loss: 1.54 Acc: 50.0
# valid Loss: 1.66 Acc: 29.8
# ==> best model saved - 2 / 29.8
# Epoch 3/99
# ----------
# train Loss: 1.41 Acc: 58.2
# valid Loss: 1.60 Acc: 32.6
# ==> best model saved - 3 / 32.6
# Epoch 4/99
# ----------
# train Loss: 1.30 Acc: 64.3
# valid Loss: 1.55 Acc: 36.2
# ==> best model saved - 4 / 36.2
# Epoch 5/99
# ----------
# train Loss: 1.17 Acc: 68.9
# valid Loss: 1.51 Acc: 38.3
# ==> best model saved - 5 / 38.3
# Epoch 6/99
# ----------
# train Loss: 1.09 Acc: 70.7
# valid Loss: 1.47 Acc: 43.3
# ==> best model saved - 6 / 43.3
# Epoch 7/99
# ----------
# train Loss: 0.98 Acc: 74.5
# valid Loss: 1.43 Acc: 45.4
# ==> best model saved - 7 / 45.4
# Epoch 8/99
# ----------
# train Loss: 0.90 Acc: 74.1
# valid Loss: 1.38 Acc: 48.2
# ==> best model saved - 8 / 48.2
# Epoch 9/99
# ----------
# train Loss: 0.83 Acc: 78.0
# valid Loss: 1.33 Acc: 53.2
# ==> best model saved - 9 / 53.2
# Epoch 10/99
# ----------
# train Loss: 0.76 Acc: 80.2
# valid Loss: 1.28 Acc: 56.7
# ==> best model saved - 10 / 56.7
# Epoch 11/99
# ----------
# train Loss: 0.72 Acc: 81.1
# valid Loss: 1.23 Acc: 57.4
# ==> best model saved - 11 / 57.4
# Epoch 12/99
# ----------
# train Loss: 0.66 Acc: 80.5
# valid Loss: 1.19 Acc: 58.9
# ==> best model saved - 12 / 58.9
# Epoch 13/99
# ----------
# train Loss: 0.61 Acc: 83.9
# valid Loss: 1.16 Acc: 61.0
99
# ----------
# train Loss: 0.07 Acc: 98.0
# valid Loss: 0.61 Acc: 83.7
# Epoch 94/99
# ----------
# train Loss: 0.06 Acc: 99.1
# valid Loss: 0.61 Acc: 83.7
# Epoch 95/99
# ----------
# train Loss: 0.07 Acc: 99.3
# valid Loss: 0.61 Acc: 83.7
# Epoch 96/99
# ----------
# train Loss: 0.08 Acc: 98.8
# valid Loss: 0.61 Acc: 84.4
# Epoch 97/99
# ----------
# train Loss: 0.08 Acc: 99.1
# valid Loss: 0.61 Acc: 84.4
# Epoch 98/99
# ----------
# train Loss: 0.08 Acc: 98.4
# valid Loss: 0.61 Acc: 84.4
# Epoch 99/99
# ----------
# train Loss: 0.06 Acc: 99.5
# valid Loss: 0.61 Acc: 84.4
# Training complete in 8m 25s
# Best valid Acc: 80 - 84.4
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 80 - 84 / 0.6

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_128_3.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_128_3.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-93-8d41c0232580>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_128_3.pt'))
# Test Loss: 0.5874
# Test Accuracy: 84.66%

# %% [markdown]
# ### batch size = 8

# %% [markdown]
# #### lr = 0.05

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# For normalization, ImageNet 데이터셋에 사용된 평균과 표준편차 사용
in_mean = (0.485, 0.456, 0.406)
in_std = (0.229, 0.224, 0.225)

# 데이터 증강 정의 (학습 데이터셋에만 적용)

# transofrms.Normalize((R채널 평균, G채널 평균, B채널 평균), (R채널 표준편차, G채널 표준편차, B채널 표준편차))

# 증강 확률의 기본값은 0.5
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    #transforms.RandomVerticalFlip(), # 상하 반전
    transforms.RandomHorizontalFlip(), # 좌우 반전
    #transforms.RandomRotation(90), #  (-degree, +degree) 사이만큼 회전
    transforms.RandomGrayscale(), # 흑백화
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.RandomErasing(),
    #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2), #색상 변화에 강한 모델
    #transforms.RandomResizedCrop(size=224, scale=(0.8, 1.0)),# 크기를 80%~100% 범위로 자른 후 크기를 맞춤
    #transforms.RandomAffine(degrees=30, translate=(0.1, 0.1), scale=(0.8, 1.2)), # 이동, 회전, 크기 변경 등을 한 번에 적용
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

# 검증 및 테스트 데이터셋에는 증강 적용 안 함
test_transform = transforms.Compose([
    transforms.ToTensor(), #  0 ~ 1 범위로 변환
    transforms.Normalize(in_mean, in_std) # 사전에 정의한 평균과 표준편차를 사용하여 정규화
])

class CustomDataset(Dataset):
    def __init__(self, X, y, mode='train'):  # mode 인자 추가
        self.X = X
        self.y = torch.tensor(y, dtype=torch.long)
        self.mode = mode  # mode 저장

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        if self.mode == 'train':
            x = train_transform(x)
        else:  # 'valid' 또는 'test'
            x = test_transform(x)
        y = self.y[idx]
        return x, y

# Dataset 생성
train_dataset = CustomDataset(x_train, y_train, mode='train')    #증강 적용
valid_dataset = CustomDataset(x_valid, y_valid, mode='valid')
test_dataset = CustomDataset(X_test, Y_test, mode='test')


## data loader 선언
dataloaders, batch_num = {}, {}
batch_size = 8

dataloaders['train'] = DataLoader(train_dataset,batch_size=batch_size, shuffle=True)   # 학습 로더에서 나오는 데이터는 항상 섞어줍니다
dataloaders['valid'] = DataLoader(valid_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다
dataloaders['test'] = DataLoader(test_dataset,batch_size=batch_size, shuffle=False)  # 평가를 위해서 순차적으로 나오게 합니다

batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  train,valid,test : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 8,  train,valid,test : 70 / 18 / 22

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 1.46 Acc: 76.6
# ==> best model saved - 0 / 76.6
# Epoch 1/99
# ----------
# train Loss: 0.04 Acc: 99.1
# valid Loss: 1.51 Acc: 75.2
# Epoch 2/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.56 Acc: 73.8
# Epoch 3/99
# ----------
# train Loss: 0.05 Acc: 98.2
# valid Loss: 1.64 Acc: 72.3
# Epoch 4/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.68 Acc: 71.6
# Epoch 5/99
# ----------
# train Loss: 0.03 Acc: 99.6
# valid Loss: 1.74 Acc: 73.0
# Epoch 6/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 1.90 Acc: 71.6
# Epoch 7/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 1.79 Acc: 73.8
# Epoch 8/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.70 Acc: 73.0
# Epoch 9/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.84 Acc: 71.6
# Epoch 10/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 1.73 Acc: 75.9
# Epoch 11/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.62 Acc: 72.3
# Epoch 12/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.72 Acc: 76.6
# Epoch 13/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 1.63 Acc: 77.3
# ==> best model saved - 13 / 77.3
# Epoch 14/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.62 Acc: 74.5
# Epoch 15/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.74 Acc: 71.6
# Epoch 16/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.63 Acc: 75.9
# Epoch 17/99
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 1.56 Acc: 73.8
# Epoch 18/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.68 Acc: 72.3
# Epoch 19/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.59 Acc: 74.5
# Epoch 20/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.67 Acc: 72.3
# Epoch 21/99
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.62 Acc: 73.8
# Epoch 22/99
# ----------
# train Loss: 0.02 Acc: 98.8
# valid Loss: 1.64 Acc: 74.5
# Epoch 23/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 1.51 Acc: 73.0
# Epoch 24/99
# ----------
# train Loss: 0.02 Acc: 98.9
# valid Loss: 1.53 Acc: 73.8
# Epoch 25/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 1.57 Acc: 75.9
# Epoch 26/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.57 Acc: 74.5
# Epoch 27/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.52 Acc: 73.8
# Epoch 28/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.48 Acc: 76.6
# Epoch 29/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 1.48 Acc: 77.3
# Epoch 30/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.53 Acc: 74.5
# Epoch 31/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 1.54 Acc: 73.8
# Epoch 32/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.57 Acc: 73.8
# Epoch 33/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.46 Acc: 75.2
# Epoch 34/99
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.49 Acc: 74.5
# Epoch 35/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.56 Acc: 74.5
# Epoch 36/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.53 Acc: 77.3
# Epoch 37/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 1.53 Acc: 75.9
# Epoch 38/99
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 1.47 Acc: 76.6
# Epoch 39/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.53 Acc: 75.2
# Epoch 40/99
# ----------
# train Loss: 0.02 Acc: 98.9
# valid Loss: 1.50 Acc: 76.6
# Epoch 41/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.49 Acc: 75.9
# Epoch 42/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.57 Acc: 75.2
# Epoch 43/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 1.51 Acc: 75.2
# Epoch 44/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.46 Acc: 76.6
# Epoch 45/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 1.47 Acc: 76.6
# Epoch 46/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 1.51 Acc: 77.3
# Epoch 47/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 1.56 Acc: 76.6
# Epoch 48/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 1.59 Acc: 75.2
# Epoch 49/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.56 Acc: 76.6
# Epoch 50/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 1.60 Acc: 75.2
# Epoch 51/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss:
99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.96 Acc: 79.4
# Epoch 45/99
# ----------
# train Loss: 0.04 Acc: 98.8
# valid Loss: 1.02 Acc: 80.9
# Epoch 46/99
# ----------
# train Loss: 0.04 Acc: 98.6
# valid Loss: 1.00 Acc: 78.0
# Epoch 47/99
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 0.89 Acc: 82.3
# Epoch 48/99
# ----------
# train Loss: 0.02 Acc: 98.9
# valid Loss: 0.90 Acc: 80.1
# Epoch 49/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.97 Acc: 80.1
# Epoch 50/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.92 Acc: 81.6
# Epoch 51/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.94 Acc: 80.1
# Epoch 52/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.89 Acc: 80.9
# Epoch 53/99
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 1.02 Acc: 78.7
# Epoch 54/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.99 Acc: 80.1
# Epoch 55/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.91 Acc: 80.1
# Epoch 56/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.92 Acc: 80.1
# Epoch 57/99
# ----------
# train Loss: 0.03 Acc: 98.6
# valid Loss: 0.94 Acc: 78.7
# Epoch 58/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.95 Acc: 78.7
# Epoch 59/99
# ----------
# train Loss: 0.04 Acc: 98.9
# valid Loss: 0.95 Acc: 79.4
# Epoch 60/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.96 Acc: 78.7
# Epoch 61/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.90 Acc: 81.6
# Epoch 62/99
# ----------
# train Loss: 0.02 Acc: 99.1
# valid Loss: 0.86 Acc: 80.1
# Epoch 63/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.86 Acc: 80.1
# Epoch 64/99
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 0.90 Acc: 81.6
# Epoch 65/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.95 Acc: 80.1
# Epoch 66/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.94 Acc: 80.9
# Epoch 67/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.94 Acc: 79.4
# Epoch 68/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.94 Acc: 80.1
# Epoch 69/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.98 Acc: 80.9
# Epoch 70/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 1.03 Acc: 80.1
# Epoch 71/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.99 Acc: 80.1
# Epoch 72/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.95 Acc: 79.4
# Epoch 73/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.94 Acc: 81.6
# Epoch 74/99
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.91 Acc: 79.4
# Epoch 75/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.93 Acc: 78.0
# Epoch 76/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.92 Acc: 78.7
# Epoch 77/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.94 Acc: 76.6
# Epoch 78/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.93 Acc: 78.7
# Epoch 79/99
# ----------
# train Loss: 0.03 Acc: 98.9
# valid Loss: 0.89 Acc: 78.7
# Epoch 80/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.91 Acc: 79.4
# Epoch 81/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.90 Acc: 80.1
# Epoch 82/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.89 Acc: 79.4
# Epoch 83/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.86 Acc: 80.1
# Epoch 84/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.91 Acc: 80.1
# Epoch 85/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.90 Acc: 80.9
# Epoch 86/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.92 Acc: 80.9
# Epoch 87/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.91 Acc: 80.9
# Epoch 88/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.90 Acc: 80.1
# Epoch 89/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.91 Acc: 81.6
# Epoch 90/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.91 Acc: 80.1
# Epoch 91/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.89 Acc: 80.9
# Epoch 92/99
# ----------
# train Loss: 0.03 Acc: 99.1
# valid Loss: 0.88 Acc: 80.1
# Epoch 93/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.93 Acc: 79.4
# Epoch 94/99
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.93 Acc: 79.4
# Epoch 95/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.92 Acc: 79.4
# Epoch 96/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.92 Acc: 79.4
# Epoch 97/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.93 Acc: 78.7
# Epoch 98/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.94 Acc: 79.4
# Epoch 99/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.95 Acc: 79.4
# Training complete in 8m 55s
# Best valid Acc: 14 - 83.7
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 14 - 84 / 0.7

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_8_2.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_8_2.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-28-c0328e6cffe3>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_8_2.pt'))
# Test Loss: 0.7064
# Test Accuracy: 81.82%

# %% [markdown]
# #### lr = 0.005

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=6)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()

            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'president_model.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(),
                         lr = 0.005,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.36 Acc: 48.4
# valid Loss: 1.22 Acc: 55.3
# ==> best model saved - 0 / 55.3
# Epoch 1/99
# ----------
# train Loss: 0.76 Acc: 72.5
# valid Loss: 0.81 Acc: 73.8
# ==> best model saved - 1 / 73.8
# Epoch 2/99
# ----------
# train Loss: 0.58 Acc: 80.9
# valid Loss: 0.62 Acc: 80.1
# ==> best model saved - 2 / 80.1
# Epoch 3/99
# ----------
# train Loss: 0.44 Acc: 85.0
# valid Loss: 0.64 Acc: 79.4
# Epoch 4/99
# ----------
# train Loss: 0.34 Acc: 88.9
# valid Loss: 0.62 Acc: 81.6
# ==> best model saved - 4 / 81.6
# Epoch 5/99
# ----------
# train Loss: 0.33 Acc: 90.0
# valid Loss: 0.55 Acc: 82.3
# ==> best model saved - 5 / 82.3
# Epoch 6/99
# ----------
# train Loss: 0.30 Acc: 90.2
# valid Loss: 0.54 Acc: 81.6
# Epoch 7/99
# ----------
# train Loss: 0.20 Acc: 93.2
# valid Loss: 0.61 Acc: 80.9
# Epoch 8/99
# ----------
# train Loss: 0.20 Acc: 94.8
# valid Loss: 0.64 Acc: 78.7
# Epoch 9/99
# ----------
# train Loss: 0.14 Acc: 96.1
99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.75 Acc: 85.8
# Epoch 93/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.74 Acc: 85.1
# Epoch 94/99
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.75 Acc: 84.4
# Epoch 95/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.75 Acc: 84.4
# Epoch 96/99
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.74 Acc: 84.4
# Epoch 97/99
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.73 Acc: 85.1
# Epoch 98/99
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.70 Acc: 86.5
# Epoch 99/99
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.70 Acc: 86.5
# Training complete in 8m 43s
# Best valid Acc: 71 - 87.2
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))
fig, ax1 = plt.subplots()

ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 71 - 87 / 0.7

# %%
# 새로운 파일 이름으로 모델 저장
torch.save(model.state_dict(), 'b0_8_3.pt')

# %%
import torch
import torch.nn as nn
from efficientnet_pytorch import EfficientNet

# 모델 구조 정의 (훈련에 사용된 동일한 모델 구조이어야 함)
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=6)

# 모델을 GPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# 저장된 가중치 불러오기
model.load_state_dict(torch.load('b0_8_3.pt'))

# 모델을 평가 모드로 전환
model.eval()

# 손실 함수와 평가 지표 정의
criterion = nn.CrossEntropyLoss()

# 정확도와 손실을 계산하는 함수 정의
def evaluate_model(model, dataloader, criterion):
    model.eval()  # 평가 모드로 전환
    running_loss = 0.0
    running_corrects = 0
    num_samples = 0

    with torch.no_grad():  # 평가 시에는 gradient 계산을 하지 않음
        for inputs, labels in dataloader:
            # 입력과 레이블을 GPU로 이동
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)  # 예측 값 구하기
            loss = criterion(outputs, labels)

            # 손실과 정확도 계산
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            num_samples += len(labels)

    epoch_loss = running_loss / num_samples
    epoch_acc = (running_corrects.double() / num_samples).cpu().item() * 100

    return epoch_loss, epoch_acc

# test 데이터셋에 대해 평가
test_loss, test_acc = evaluate_model(model, dataloaders['test'], criterion)

# 결과 출력
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Loaded pretrained weights for efficientnet-b0
# <ipython-input-35-879eb301428f>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('b0_8_3.pt'))
# Test Loss: 0.6004
# Test Accuracy: 84.66%
